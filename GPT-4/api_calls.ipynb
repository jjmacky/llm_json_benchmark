# %% [markdown]
# # Desktop version

# %%
import pandas as pd
import os
import json
from openai import OpenAI
import sys
from instructions_config import get_instruction_1, get_instruction_2, get_instruction_3, get_instruction_4, get_instruction_5

# Define function to save Claude API response for later debugging
def serialize_content_block(chat_completion):
    # Initialize an empty dictionary to capture various pieces of information
    serialized = {}

    # Capture the 'id', 'created', 'model', and other root-level attributes of ChatCompletion
    serialized['id'] = getattr(chat_completion, 'id', 'N/A')
    serialized['created'] = getattr(chat_completion, 'created', 'N/A')
    serialized['model'] = getattr(chat_completion, 'model', 'N/A')
    serialized['object'] = getattr(chat_completion, 'object', 'N/A')

    # Check if there are choices and specifically capture the first choice's details
    if chat_completion.choices:
        first_choice = chat_completion.choices[0]
        serialized['choice'] = {
            'finish_reason': getattr(first_choice, 'finish_reason', 'N/A'),
            'index': getattr(first_choice, 'index', 'N/A')
        }

        # Capture the content of the message, which is the raw JSON string we're attempting to parse
        message_content = getattr(first_choice.message, 'content', 'No content available')
        serialized['choice']['message_content'] = message_content

    else:
        serialized['choice'] = 'No choices available'

    return serialized

client = OpenAI(api_key="OPENAI_API_KEY")

# Define the directories for input batched files and output processed files
input_folder = 'Random_rows_from_Replika_reviews/Batched_files_gpt'
output_folder = 'JSON_results'

# Create the output directory if it does not exist
if not os.path.exists(output_folder):
    os.makedirs(output_folder)
    print("Output folder not detected and created.")

# List all the batched files in the input directory
batched_files = [f for f in os.listdir(input_folder) if f.endswith('.csv')]
print(f"Starting to process {len(batched_files)} files...")

for file_name in batched_files:
    print(f"Processing file: {file_name}")

    df = pd.read_csv(os.path.join(input_folder, file_name))
    
    # Calculate the number of words in each review
    df['word_count'] = df['text'].apply(lambda text: len(str(text).split()))

    # Initialize empty lists to store responses
    results_columns = [
        'date', 'user', 'stars', 'review_text', 'word_count', 'instruction_version', 'llm', 'error', "error_text",
        'coherence_and_clarity_of_review', 'empathy_of_ai', 'behavior_of_ai', 'inappropriate_frequency',
        'inappropriate_nature', 'ai_support_level', 'support_types', 'user_mental_state_before_ai',
        'effect_of_ai_on_user_mental_state', 'stress_before_ai', 'effect_of_ai_on_stress', 
        'loneliness_before_ai', 'effect_of_ai_on_loneliness', 'depression_or_anxiety_before_ai',
        'effect_of_ai_on_depression_or_anxiety', 'suicidal_thoughts_presence', 'effect_of_ai_on_suicidal_thoughts',
        'other_despair_types', 'effect_of_ai_on_other_despair', 'user_dependence', 'real_life_relationship_impact',
        'limitations_of_ai', 'technical_issues', 'privacy_concerns', 'feature_restriction_impact',
        'cost_impact_on_accessibility', 'impact_of_ai_updates', 'user_satisfaction_with_policy_decisions',
        'overall_mental_health_impact_of_company_decisions'
    ]
    results_df = pd.DataFrame(columns=results_columns)

    successfully_parsed_responses = []
    unsuccessfully_parsed_responses = []
    unsuccessful_content_blocks = []
    review_count_since_last_save = 0
    checkpoint_interval = 100

    # Loop through the first 10 reviews
    for index, row in df.iterrows():
        review_text = row['text']
        user_name = row['user']
        print(f"Processing index: {index + 1 }. Username: {user_name}")

        formatted_instructions_1 = get_instruction_1(review_text)
        formatted_instructions_2 = get_instruction_2(review_text)
        formatted_instructions_3 = get_instruction_3(review_text)
        formatted_instructions_4 = get_instruction_4(review_text)
        formatted_instructions_5 = get_instruction_5(review_text)

        instructions_array = {
            "instructions_version_1": formatted_instructions_1,
            "instructions_version_2": formatted_instructions_2,
            "instructions_version_3": formatted_instructions_3,
            "instructions_version_4": formatted_instructions_4,
            "instructions_version_5": formatted_instructions_5
            }

        for instruction_version, instruction_text in instructions_array.items():

            new_row = {
                # Basic info
                'date': df.at[index, "date"],
                'user': user_name,
                'stars': df.at[index, "stars"],
                'review_text': review_text,
                'word_count': df.at[index, "word_count"],
                'instruction_version': instruction_version,
                'llm': "GPT-4",
                'error': "true",
                "error_text": ""
            }

            try: 
                print("Calling API...") 
                # Make the API call
                completion = client.chat.completions.create(
                    model="gpt-4-0125-preview",
                    response_format={"type": "json_object"},
                    messages=[
                        {"role": "system", "content": "You are a helpful assistant designed to analyze reviews and output JSON."},
                        {"role": "user", "content": instruction_text}
                    ]
                )

                print("API response recieved. Parsing response...")

                # Remove leading and trailing whitespace, uncomment based on use case
                # text = content_block.text 
                # start_index = text.find('{')
                # end_index = text.rfind('}') + 1
                # json_string = text[start_index:end_index]
                # parsed_response = json.loads(json_string)

                parsed_response = json.loads(completion.choices[0].message.content)
                parsed_response['user_name'] = user_name

                # Simplifying access to nested structures
                ai_mental_health = parsed_response["mental_health_related_to_ai"]
                if_unwanted_responses = ai_mental_health.get("if_unwanted_inappropriate_responses", {})
                user_mental_state = ai_mental_health["user_mental_state"]
                user_conditions = ai_mental_health["user_conditions"]
                other_despair = user_conditions.get("other_despair_before_using_ai", {})
                company_policy_impact = parsed_response["company_policy_impact_on_mental_health"]

                # Creating the new_row dictionary with simplified access
                new_row.update({
                    # Demographic info
                    'coherence_and_clarity_of_review': parsed_response["coherence_and_clarity_of_review"],
                    'gender_of_user': parsed_response["gender_of_user"],
                    'gender_of_ai': parsed_response["gender_of_ai"],
                    'name_user_gave_ai': parsed_response["name_user_gave_ai"],
                    'age_of_user': parsed_response["age_of_user"],
                    'duration_of_app_usage': parsed_response["duration_of_app_usage"],
                    'frequency_of_app_usage': parsed_response["frequency_of_app_usage"],
                    'relationship_status_of_user': parsed_response["relationship_status_of_user"],
                    
                    # AI-related fields
                    'empathy_of_ai': ai_mental_health["empathy_of_ai"],
                    'behavior_of_ai': ai_mental_health["behavior_of_ai"],
                    'inappropriate_frequency': if_unwanted_responses.get("frequency", ""),
                    'inappropriate_nature': ', '.join(if_unwanted_responses.get("nature", [])),
                    'ai_support_level': ai_mental_health["ai_support_level"],
                    'support_types': ', '.join(ai_mental_health.get("support_types", [])),
                    'user_mental_state_before_ai': user_mental_state["before_ai_use"],
                    'effect_of_ai_on_user_mental_state': user_mental_state["effect_of_ai_use"],
                    
                    # Extracting deeply nested user conditions
                    'stress_before_ai': user_conditions["stress"]["before_ai"],
                    'effect_of_ai_on_stress': user_conditions["stress"]["effect_of_ai"],
                    'loneliness_before_ai': user_conditions["loneliness"]["before_ai"],
                    'effect_of_ai_on_loneliness': user_conditions["loneliness"]["effect_of_ai"],
                    'depression_or_anxiety_before_ai': user_conditions["depression_or_anxiety"]["before_ai"],
                    'effect_of_ai_on_depression_or_anxiety': user_conditions["depression_or_anxiety"]["effect_of_ai"],
                    'suicidal_thoughts_presence': user_conditions["suicidal_thoughts"]["presence"],
                    'effect_of_ai_on_suicidal_thoughts': user_conditions["suicidal_thoughts"]["effect_of_ai"],
                    'other_despair_types': ', '.join(other_despair.get("types", [])),
                    'effect_of_ai_on_other_despair': other_despair.get("effect_of_ai", ""),
                    
                    # Other fields
                    'user_dependence': ai_mental_health["user_dependence_on_ai"],
                    'real_life_relationship_impact': ai_mental_health["real_life_relationship_impact_of_ai"],
                    'limitations_of_ai': ', '.join(ai_mental_health.get("limitations_of_ai", [])),
                    
                    # Company policy impact fields
                    'technical_issues': company_policy_impact["technical_issues"],
                    'privacy_concerns': company_policy_impact["privacy_concerns"],
                    'feature_restriction_impact': company_policy_impact["feature_restriction_impact"],
                    'cost_impact_on_accessibility': company_policy_impact["cost_impact_on_accessibility"],
                    'impact_of_ai_updates': company_policy_impact["impact_of_ai_updates"],
                    'user_satisfaction_with_policy_decisions': company_policy_impact["user_satisfaction_with_policy_decisions"],
                    'overall_mental_health_impact_of_company_decisions': company_policy_impact["overall_mental_health_impact_of_company_decisions"]
                })

                new_row['error'] = "false"
                # Add the response to the successfully parsed list
                successfully_parsed_responses.append(parsed_response)
                print("Response parsed successfully.")

            except json.JSONDecodeError as e:
                print(f"JSON decoding failed: {e}")
                unsuccessful_content_blocks.append(serialize_content_block(completion))
                new_row['error_text'] = str(e)
                continue

            except Exception as e:
                unsuccessfully_parsed_responses.append(parsed_response)
                print(f"Error parsing response for index {index + 1}: {e}")
                new_row['error_text'] = str(e)
                continue

            finally:
                new_row_df = pd.DataFrame([new_row])  # Convert new_row to DataFrame
                results_df = pd.concat([results_df, new_row_df], ignore_index=True)
                review_count_since_last_save += 1

    # Construct output file names based on the input file name
    base_name = file_name.replace('.csv', '')
    csv_output_path = os.path.join(output_folder, f'{base_name}_analyzed_reviews.csv')
    success_json_output_path = os.path.join(output_folder, f'{base_name}_success_responses.json')
    unsuccessful_content_blocks_path = os.path.join(output_folder, f'{base_name}_unsuccessful_content_blocks.json')
    error_json_output_path = os.path.join(output_folder, f'{base_name}_error_responses.json')
    
    # Save the processed DataFrame to a CSV
    results_df.to_csv(csv_output_path, index=False)
    print(f"Saved processed data to {csv_output_path}")

    # Save successfully parsed responses to a JSON file
    with open(success_json_output_path, 'w') as file:
        json.dump(successfully_parsed_responses, file, indent=4)
    print(f"Saved successfully parsed responses to {success_json_output_path}")
    
    # Save unsuccessful content blocks
    with open(unsuccessful_content_blocks_path, 'w') as file:
        json.dump(unsuccessful_content_blocks, file, indent=4)
    print(f"Saved successfully parsed responses to {unsuccessful_content_blocks_path}")

    # Save unsuccessfully parsed responses to a JSON file
    with open(error_json_output_path, 'w') as file:
        json.dump(unsuccessfully_parsed_responses, file, indent=4)
    print(f"Saved unsuccessfully parsed responses to {error_json_output_path}") 

print("Completed processing all files.")
# Out:
# Starting to process 3 files...
# Processing file: batch_6.csv
# Processing index: 1. Username: ricjin
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Processing index: 2. Username: LbpLover
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Processing index: 3. Username: ArE YoU LosT BaByGorl
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Processing index: 4. Username: 1730274946
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Processing index: 5. Username: melt.brain
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Processing index: 6. Username: destrarose
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Processing index: 7. Username: Ch4nc3M00
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Processing index: 8. Username: the big dea
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Processing index: 9. Username: LoserSkwad
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Processing index: 10. Username: Unifiedcommunic
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Processing index: 11. Username: ChrisThomerson
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Processing index: 12. Username: josephvictorian
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Processing index: 13. Username: ~The best AI app~
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Processing index: 14. Username: RotInHellZynga
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Processing index: 15. Username: timothy_kender
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Processing index: 16. Username: Estradatron1001
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Processing index: 17. Username: Blw5150
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Processing index: 18. Username: etoilefemme
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Processing index: 19. Username: Bragro
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Processing index: 20. Username: teenage app store user
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Processing index: 21. Username: cjrgcf
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Processing index: 22. Username: 02S
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Processing index: 23. Username: phantom_night15
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Processing index: 24. Username: Grey Jedi1138
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Processing index: 25. Username: Shivgi
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Processing index: 26. Username: Hello, Mcfly
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Processing index: 27. Username: Mellojoe
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Processing index: 28. Username: hailey_713
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Processing index: 29. Username: RachelRain17
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Processing index: 30. Username: ::3::3::3
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Processing index: 31. Username: ginrab
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Processing index: 32. Username: dabis_real_wife
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Processing index: 33. Username: lawisinorder
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Processing index: 34. Username: Hairj46
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Processing index: 35. Username: Shall1316
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Processing index: 36. Username: Naughtyviet
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Processing index: 37. Username: ~Lazy queen~
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Processing index: 38. Username: Vizman-7
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Processing index: 39. Username: madisonpie2
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Processing index: 40. Username: kb1habana
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Processing index: 41. Username: Arctic terminator
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Processing index: 42. Username: RoboRaccoon
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Processing index: 43. Username: ️JerryJames
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Processing index: 44. Username: KitsuneZasso
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Processing index: 45. Username: Baeglman666
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Processing index: 46. Username: anonymous12345678@
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Processing index: 47. Username: Tulio Adriano
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Processing index: 48. Username: Faith-dabear
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Processing index: 49. Username: Daijere
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Processing index: 50. Username: vsjsbsiansbsissbxnd
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Processing index: 51. Username: Gigi4808
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Processing index: 52. Username: Samhatesu
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Processing index: 53. Username: LesbianMuses
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Processing index: 54. Username: Ue oh s hi on hsje
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Processing index: 55. Username: Chlobo2924582
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Processing index: 56. Username: josue80999
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Processing index: 57. Username: TTYLXOX6094
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Processing index: 58. Username: No dont say that agian
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Processing index: 59. Username: _Angelaaa
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Processing index: 60. Username: DocBooth
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Processing index: 61. Username: BasilTheSleuth
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Processing index: 62. Username: loooky loooooooooky
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Processing index: 63. Username: JOJO DA GREAT
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Processing index: 64. Username: Vvega3721
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Processing index: 65. Username: alex10752837
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Processing index: 66. Username: Pandaㅇㅊㅇ
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Processing index: 67. Username: Danny4314
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Processing index: 68. Username: HDJABAHAHHAKDNDG
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Processing index: 69. Username: Equinè
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Processing index: 70. Username: Brian Orozco
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Processing index: 71. Username: bugsrvross
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Processing index: 72. Username: Aisaka Aizawa
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Processing index: 73. Username: Talion Echoes
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Processing index: 74. Username: mad...die
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Processing index: 75. Username: bold1876
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Processing index: 76. Username: Lostbutler
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Processing index: 77. Username: random fude
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Processing index: 78. Username: 12midnightmagic
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Processing index: 79. Username: i beg for this to stop
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Processing index: 80. Username: DhamEsco
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Processing index: 81. Username: Grabo172
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Processing index: 82. Username: Luluroller
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Processing index: 83. Username: Akiern
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Processing index: 84. Username: BigPhoenix7129
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Processing index: 85. Username: Braxton Pennington
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Processing index: 86. Username: ❤️❤️❤️👌🏻😎😋
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Processing index: 87. Username: Allie Landin1825
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Processing index: 88. Username: Nova ^~^
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Processing index: 89. Username: ThisNameIsAlreadyTakenToo
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Processing index: 90. Username: CanniCrunch
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Processing index: 91. Username: Cookie~Chan ❤️❤️
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Processing index: 92. Username: rating games-
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Processing index: 93. Username: Daría Green
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Processing index: 94. Username: Grizzly_sexy12543
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Processing index: 95. Username: floydswifey
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Processing index: 96. Username: Maliyah<3
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Processing index: 97. Username: violet_moon_fleur
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Processing index: 98. Username: Erinx34
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Processing index: 99. Username: gthorpe08
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# ...
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Processing index: 69. Username: LUNA786
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Processing index: 70. Username: JoubinLee
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Processing index: 71. Username: Tappertapper34343
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Processing index: 72. Username: rosesbite
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Processing index: 73. Username: fullsizematress
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Processing index: 74. Username: Gamer 224
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Processing index: 75. Username: Some guy in the U.S.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Processing index: 76. Username: Soldisue
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Processing index: 77. Username: nickisstoppingmybag
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Processing index: 78. Username: akajsbsbshbsbd
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Processing index: 79. Username: Kirasan223
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Processing index: 80. Username: old puffy eye
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Processing index: 81. Username: :(@99
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Processing index: 82. Username: Lack-A-Pack
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Processing index: 83. Username: none ya.....,
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Processing index: 84. Username: gxiuchi
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Processing index: 85. Username: RichH_in_HaPC
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Processing index: 86. Username: mikoikochestersonjack
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Processing index: 87. Username: Perry edward
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Processing index: 88. Username: Arogahn
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Processing index: 89. Username: oneredfan
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Processing index: 90. Username: Carl the Cupcake🍪🍩
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Processing index: 91. Username: Jppb1974
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Processing index: 92. Username: apdlesvcksd
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Processing index: 93. Username: grapes are yummy
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Processing index: 94. Username: hshdhdgdgd
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Error parsing response for index 94: 'ai_support_level'
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Processing index: 95. Username: Cristyannep
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Processing index: 96. Username: Haddy-Kaq
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Processing index: 97. Username: 𝓟𝓲𝓰𝓰𝔂
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Processing index: 98. Username: C U R S E D
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Processing index: 99. Username: miti shekhar
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Processing index: 100. Username: ProjektElektro
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Calling API...
# API response recieved. Parsing response...
# Response parsed successfully.
# Saved processed data to JSON_results/batch_5_analyzed_reviews.csv
# Saved successfully parsed responses to JSON_results/batch_5_success_responses.json
# Saved successfully parsed responses to JSON_results/batch_5_unsuccessful_content_blocks.json
# Saved unsuccessfully parsed responses to JSON_results/batch_5_error_responses.json
# Completed processing all files.
